# %% [markdown]
# <a href="https://colab.research.google.com/github/satyam123457/music-recomm-system/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import Recommenders as Recommenders
import matplotlib.pyplot as plt
import seaborn as sb
import tensorflow as tf

# %%
from sklearn.metrics.pairwise import cosine_similarity
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.manifold import TSNE
 
import warnings
warnings.filterwarnings('ignore')

#next line 
song_df_1 = pd.read_csv('triplets_file.csv')
song_df_1.head()
# Out:
#                                     user_id             song_id  listen_count
# 0  b80344d063b5ccb3212f76538f3d9e43d87dca9e  SOAKIMP12A8C130995           1.0
# 1  b80344d063b5ccb3212f76538f3d9e43d87dca9e  SOBBMDR12A8C13253B           2.0
# 2  b80344d063b5ccb3212f76538f3d9e43d87dca9e  SOBXHDL12A81C204C0           1.0
# 3  b80344d063b5ccb3212f76538f3d9e43d87dca9e  SOBYHAJ12A6701BF1D           1.0
# 4  b80344d063b5ccb3212f76538f3d9e43d87dca9e  SODACBL12A8C13C273           1.0

# %%
song_df_2 = pd.read_csv('song_data.csv')
song_df_2.head()
# Out:
#               song_id              title  \
# 0  SOQMMHC12AB0180CB8       Silent Night
# 1  SOVFVAK12A8C1350D9        Tanssi vaan
# 2  SOGTUKN12AB017F4F1  No One Could Ever
# 3  SOBNYVR12A8C13558C      Si Vos Querés
# 4  SOHSBXH12A8C13B0DF   Tangle Of Aspens
#
#                                 release       artist_name    year
# 0                 Monster Ballads X-Mas  Faster Pussy cat  2003.0
# 1                           Karkuteillä  Karkkiautomaatti  1995.0
# 2                                Butter    Hudson Mohawke  2006.0
# 3                               De Culo       Yerba Brava  2003.0
# 4  Rene Ablaze Presents Winter Sessions        Der Mystic     0.0

# %%
# combine both data
song_df = pd.merge(song_df_1, song_df_2.drop_duplicates(['song_id']), on='song_id', how='left')
song_df.head()
# Out:
#                                     user_id             song_id  listen_count  \
# 0  b80344d063b5ccb3212f76538f3d9e43d87dca9e  SOAKIMP12A8C130995           1.0
# 1  b80344d063b5ccb3212f76538f3d9e43d87dca9e  SOBBMDR12A8C13253B           2.0
# 2  b80344d063b5ccb3212f76538f3d9e43d87dca9e  SOBXHDL12A81C204C0           1.0
# 3  b80344d063b5ccb3212f76538f3d9e43d87dca9e  SOBYHAJ12A6701BF1D           1.0
# 4  b80344d063b5ccb3212f76538f3d9e43d87dca9e  SODACBL12A8C13C273           1.0
#
#              title              release    artist_name    year
# 0              NaN                  NaN            NaN     NaN
# 1  Entre Dos Aguas  Flamenco Para Niños  Paco De Lucia  1976.0
# 2         Stronger           Graduation     Kanye West  2007.0
# 3              NaN                  NaN            NaN     NaN
# 4              NaN                  NaN            NaN     NaN

# %%
# creating new feature combining title and artist name
song_df['song'] = song_df['title']+' - '+song_df['artist_name']
song_df.head()
# Out:
#                                     user_id             song_id  listen_count  \
# 0  b80344d063b5ccb3212f76538f3d9e43d87dca9e  SOAKIMP12A8C130995           1.0
# 1  b80344d063b5ccb3212f76538f3d9e43d87dca9e  SOBBMDR12A8C13253B           2.0
# 2  b80344d063b5ccb3212f76538f3d9e43d87dca9e  SOBXHDL12A81C204C0           1.0
# 3  b80344d063b5ccb3212f76538f3d9e43d87dca9e  SOBYHAJ12A6701BF1D           1.0
# 4  b80344d063b5ccb3212f76538f3d9e43d87dca9e  SODACBL12A8C13C273           1.0
#
#              title              release    artist_name    year  \
# 0              NaN                  NaN            NaN     NaN
# 1  Entre Dos Aguas  Flamenco Para Niños  Paco De Lucia  1976.0
# 2         Stronger           Graduation     Kanye West  2007.0
# 3              NaN                  NaN            NaN     NaN
# 4              NaN                  NaN            NaN     NaN
#
#                               song
# 0                              NaN
# 1  Entre Dos Aguas - Paco De Lucia
# 2            Stronger - Kanye West
# 3                              NaN
# 4                              NaN

# %%
# taking top 10k samples for quick results
song_df = song_df.head(10000)

# %%
# cummulative sum of listen count of the songs
song_grouped = song_df.groupby(['song']).agg({'listen_count':'count'}).reset_index()
song_grouped.head()
# Out:
#                                       song  listen_count
# 0                 #40 - DAVE MATTHEWS BAND             1
# 1  (Anaesthesia) Pulling Teath - Metallica             1
# 2                              143 - Musiq             2
# 3                            42 - Coldplay             2
# 4       A Better Son/Daughter - Rilo Kiley             1

# %%
grouped_sum = song_grouped['listen_count'].sum()
song_grouped['percentage'] = (song_grouped['listen_count'] / grouped_sum ) * 100
song_grouped.sort_values(['listen_count', 'song'], ascending=[0,1])
# Out:
#                                                   song  listen_count  \
# 830                                       Undo - Björk            32
# 194  Dog Days Are Over (Radio Edit) - Florence + Th...            28
# 443  Lucky (Album Version) - Jason Mraz & Colbie Ca...            20
# 508  Nothin' On You [feat. Bruno Mars] (Album Versi...            16
# 162               Cosmic Love - Florence + The Machine            15
# ..                                                 ...           ...
# 919                            Your Woman - White Town             1
# 920                          Zero - The Pain Machinery             1
# 923                              high fives - Four Tet             1
# 924             paranoid android - Christopher O'Riley             1
# 927                              Época - Gotan Project             1
#
#      percentage
# 830    1.752464
# 194    1.533406
# 443    1.095290
# 508    0.876232
# 162    0.821468
# ..          ...
# 919    0.054765
# 920    0.054765
# 923    0.054765
# 924    0.054765
# 927    0.054765
#
# [928 rows x 3 columns]

# %%
pr = Recommenders.popularity_recommender_py()
pr.create(song_df, 'user_id', 'song')
# display the top 10 popular songs
pr.recommend(song_df['user_id'][5])
# Out:
#                                       user_id  \
# 830  b80344d063b5ccb3212f76538f3d9e43d87dca9e
# 194  b80344d063b5ccb3212f76538f3d9e43d87dca9e
# 443  b80344d063b5ccb3212f76538f3d9e43d87dca9e
# 508  b80344d063b5ccb3212f76538f3d9e43d87dca9e
# 162  b80344d063b5ccb3212f76538f3d9e43d87dca9e
# 548  b80344d063b5ccb3212f76538f3d9e43d87dca9e
# 289  b80344d063b5ccb3212f76538f3d9e43d87dca9e
# 761  b80344d063b5ccb3212f76538f3d9e43d87dca9e
# 26   b80344d063b5ccb3212f76538f3d9e43d87dca9e
# 402  b80344d063b5ccb3212f76538f3d9e43d87dca9e
#
#                                                   song  score  Rank
# 830                                       Undo - Björk     32   1.0
# 194  Dog Days Are Over (Radio Edit) - Florence + Th...     28   2.0
# 443  Lucky (Album Version) - Jason Mraz & Colbie Ca...     20   3.0
# 508  Nothin' On You [feat. Bruno Mars] (Album Versi...     16   4.0
# 162               Cosmic Love - Florence + The Machine     15   5.0
# 548                  Party In The U.S.A. - Miley Cyrus     14   6.0
# 289          Harder Better Faster Stronger - Daft Punk     13   7.0
# 761      The Only Exception (Album Version) - Paramore     12   8.0
# 26   Ain't No Rest For The Wicked (Original Version...     11   9.0
# 402                          Kryptonite - 3 Doors Down     11  10.0

# %%
ir = Recommenders.item_similarity_recommender_py()
ir.create(song_df, 'user_id', 'song')
user_items = ir.get_user_items(song_df['user_id'][5])
# display user songs history
for user_item in user_items:
    print(user_item)
# Out:
# nan
# Entre Dos Aguas - Paco De Lucia
# Stronger - Kanye West
# Heaven's gonna burn your eyes - Thievery Corporation feat. Emiliana Torrini
# Let It Be Sung - Jack Johnson / Matt Costa / Zach Gill / Dan Lebowitz / Steve Adams
# I'll Be Missing You (Featuring Faith Evans & 112)(Album Version) - Puff Daddy
# Behind The Sea [Live In Chicago] - Panic At The Disco
# Oh No - Andrew Bird
# Love Song For No One - John Mayer
# The Christmas Song  (LP Version) - King Curtis

# %%
# give song recommendation for that user
ir.recommend(song_df['user_id'][5])
# Out:
# No. of unique songs for the user: 10
# no. of unique songs in the training set: 929
# Non zero values in cooccurence_matrix :258
#                                     user_id  \
# 0  b80344d063b5ccb3212f76538f3d9e43d87dca9e
# 1  b80344d063b5ccb3212f76538f3d9e43d87dca9e
# 2  b80344d063b5ccb3212f76538f3d9e43d87dca9e
# 3  b80344d063b5ccb3212f76538f3d9e43d87dca9e
# 4  b80344d063b5ccb3212f76538f3d9e43d87dca9e
# 5  b80344d063b5ccb3212f76538f3d9e43d87dca9e
# 6  b80344d063b5ccb3212f76538f3d9e43d87dca9e
# 7  b80344d063b5ccb3212f76538f3d9e43d87dca9e
# 8  b80344d063b5ccb3212f76538f3d9e43d87dca9e
# 9  b80344d063b5ccb3212f76538f3d9e43d87dca9e
#
#                                                 song     score  rank
# 0                            Plástico - Ruben Blades  0.050000     1
# 1                 Drunken Lullabies - Flogging Molly  0.037500     2
# 2  Crazy For You No Kisetsu (Album Version) - Bas...  0.033333     3
# 3       DONTTRUSTME (Explicit Album Version) - 3OH!3  0.033333     4
# 4              The Warrior's Code - Dropkick Murphys  0.033333     5
# 5                          Dark Matter - Andrew Bird  0.033333     6
# 6                       Not Falling Apart - Maroon 5  0.033333     7
# 7                                Ddiamondd - Battles  0.033333     8
# 8  Once In A Lifetime (Remastered LP Version ) - ...  0.033333     9
# 9                      Down By The Water - PJ Harvey  0.033333    10

# %% [markdown]
# 2nd program initialise

# %%
spoti = pd.read_csv("genres_v2.csv", encoding='utf-8', quotechar='"')
spoti.head(3)
# Out:
#    danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0         0.831   0.814    2    -7.364     1       0.4200        0.0598
# 1         0.719   0.493    8    -7.230     1       0.0794        0.4010
# 2         0.850   0.893    5    -4.783     1       0.0623        0.0138
#
#    instrumentalness  liveness  valence  ...                      id  \
# 0          0.013400    0.0556   0.3890  ...  2Vc6NJ9PW9gD9q343XFRKx
# 1          0.000000    0.1180   0.1240  ...  7pgJBLVz5VmnL7uGHmRj6p
# 2          0.000004    0.3720   0.0391  ...  0vSWgAlfpye0WCGeNmuNhy
#
#                                     uri  \
# 0  spotify:track:2Vc6NJ9PW9gD9q343XFRKx
# 1  spotify:track:7pgJBLVz5VmnL7uGHmRj6p
# 2  spotify:track:0vSWgAlfpye0WCGeNmuNhy
#
#                                           track_href  \
# 0  https://api.spotify.com/v1/tracks/2Vc6NJ9PW9gD...
# 1  https://api.spotify.com/v1/tracks/7pgJBLVz5Vmn...
# 2  https://api.spotify.com/v1/tracks/0vSWgAlfpye0...
#
#                                         analysis_url duration_ms  \
# 0  https://api.spotify.com/v1/audio-analysis/2Vc6...      124539
# 1  https://api.spotify.com/v1/audio-analysis/7pgJ...      224427
# 2  https://api.spotify.com/v1/audio-analysis/0vSW...       98821
#
#   time_signature      genre            song_name Unnamed: 0 title
# 0              4  Dark Trap  Mercury: Retrograde        NaN   NaN
# 1              4  Dark Trap            Pathology        NaN   NaN
# 2              4  Dark Trap             Symbiote        NaN   NaN
#
# [3 rows x 22 columns]

# %%
spoti.shape
# Out:
# (42305, 22)

# %%
song_name = spoti["song_name"]
print(song_name.shape)
print(song_name.isnull().values.any())
# Out:
# (42305,)
# True

# %%
song_name = song_name.values.reshape(-1,1)
song_name.shape
# Out:
# (42305, 1)

# %%
from sklearn.impute import SimpleImputer
imr = SimpleImputer(missing_values=np.nan, strategy='most_frequent')
imr = imr.fit(song_name)
imputed_data = imr.transform(song_name)
song_name = pd.DataFrame(imputed_data)
song_name = song_name.rename(columns={0:"Song-Names"})
song_name.head(3)
# Out:
#             Song-Names
# 0  Mercury: Retrograde
# 1            Pathology
# 2             Symbiote

# %%
core = spoti[["genre","mode","duration_ms"]]
print(core.dtypes)
print(core.head())
# Out:
# genre          object
# mode            int64
# duration_ms     int64
# dtype: object
#        genre  mode  duration_ms
# 0  Dark Trap     1       124539
# 1  Dark Trap     1       224427
# 2  Dark Trap     1        98821
# 3  Dark Trap     1       123661
# 4  Dark Trap     1       123298

# %%
core.dtypes
# Out:
# genre          object
# mode            int64
# duration_ms     int64
# dtype: object

# %%
core["genre"].value_counts()
# Out:
# Underground Rap    5875
# Dark Trap          4578
# Hiphop             3028
# trance             2999
# trap               2987
# techhouse          2975
# dnb                2966
# psytrance          2961
# techno             2956
# hardstyle          2936
# RnB                2099
# Trap Metal         1956
# Rap                1848
# Emo                1680
# Pop                 461
# Name: genre, dtype: int64

# %%
core = core.replace({"genre":{"Underground Rap":0, "Dark Trap":1, "Hiphop":2, "trance":3, "trap":4, "techhouse":5, "dnb":6, "psytrance": 7, "techno":8, "hardstyle":9, "RnB":10, "Trap Metal":11, "Rap":12, "Emo":13, "Pop":14}})

# %%
from sklearn.decomposition import NMF
nmf = NMF(n_components = 6)
nmf_features = nmf.fit_transform(core)

# %%
from sklearn.preprocessing import normalize
norm_features = normalize(nmf_features)
current_music = norm_features[23,:]
similarities = norm_features.dot(current_music)
similarities
# Out:
# array([0.96511152, 0.86542566, 0.89997856, ..., 0.93454209, 0.8667171 ,
#        0.89776721])

# %%
df = pd.DataFrame(norm_features)
x = df.join(song_name)
df = pd.pivot_table(x, x[[0,1,2,3,4,5]],["Song-Names"])#for indexing song_name to our df
def current_music(value):
    print("Top 5 recommendations for given music are:")
    value = df.loc[value]
    similarities = df.dot(value)
    print(format(similarities.nlargest()))

# %%
current_music("Missed Calls - Remix")
# Out:
# Top 5 recommendations for given music are:
# Song-Names
# Missed Calls - Remix    1.000000
# 2 Fake                  0.999845
# IAMGOD                  0.999784
# Aulos Reloaded          0.999375
# Memphis to La           0.999323
# dtype: float64

# %%
current_music("SEARCH & DESTRXY.")
# Out:
# Top 5 recommendations for given music are:
# Song-Names
# SEARCH & DESTRXY.        1.000000
# Welcome to the Jungle    0.999902
# Outlaw                   0.999491
# 2002 / Asia Interlude    0.998780
# Staplegunned             0.997729
# dtype: float64

# %%
current_music("Animals")
# Out:
# Top 5 recommendations for given music are:
# Song-Names
# Ride (feat. Kehlani)                0.983787
# Up Late                             0.983295
# Omni Nocte                          0.982933
# Beautiful (feat. Camila Cabello)    0.982899
# Triggered (freestyle)               0.982668
# dtype: float64
